# %%
from pathlib import Path
import pandas as pd

RACE_DIR = Path(
    "../data/raw/2022/Monaco_Grand_Prix"

)

laps = pd.read_csv(RACE_DIR / "laps.csv")
weather = pd.read_csv(RACE_DIR / "weather.csv")
results = pd.read_csv(RACE_DIR / "results.csv")
track_status = pd.read_csv(RACE_DIR / "track_status.csv")
race_control = pd.read_csv(RACE_DIR / "race_control.csv")

# %%
print("LAPS")
print(laps.shape)
print(laps.columns.tolist())

print("\nWEATHER")
print(weather.shape)
print(weather.columns.tolist())

print("\nRESULTS")
print(results.shape)
print(results.columns.tolist())

print("\nTRACK STATUS")
print(track_status.shape)
print(track_status.columns.tolist())

print("\nRACE CONTROL")
print(race_control.shape)
print(race_control.columns.tolist())
# Out:
# LAPS
# (1179, 31)
# ['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime', 'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest', 'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime', 'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason', 'FastF1Generated', 'IsAccurate']
#
# WEATHER
# (245, 8)
# ['Time', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed']
#
# RESULTS
# (20, 22)
# ['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName', 'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName', 'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition', 'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'Laps']
#
# TRACK STATUS
# (31, 3)
# ['Time', 'Status', 'Message']
#
# RACE CONTROL
# (168, 9)
# ...
